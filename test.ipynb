# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('/Users/colin/Downloads/IDX Exchange/raw/CRMLSSold202603.csv')

df.head(10)
df['ListingKey'].head()
# Out:
# 0    1156815844
# 1    1156789232
# 2    1156759650
# 3    1156727153
# 4    1156726807
# Name: ListingKey, dtype: int64

# %%
dct = {name: 0 for name in df.columns}

print(dct)

# pct null per column
for col in df:
    dct[col] = round((int(df[col].isna().sum()) / len(df[col])) * 100, 2)

print(dct)
# Out:
# {'BuyerAgentAOR': 0, 'ListAgentAOR': 0, 'Flooring': 0, 'ViewYN': 0, 'WaterfrontYN': 0, 'BasementYN': 0, 'PoolPrivateYN': 0, 'OriginalListPrice': 0, 'ListingKey': 0, 'CloseDate': 0, 'ClosePrice': 0, 'ListAgentFirstName': 0, 'ListAgentLastName': 0, 'Latitude': 0, 'Longitude': 0, 'UnparsedAddress': 0, 'PropertyType': 0, 'LivingArea': 0, 'ListPrice': 0, 'DaysOnMarket': 0, 'ListOfficeName': 0, 'BuyerOfficeName': 0, 'CoListOfficeName': 0, 'ListAgentFullName': 0, 'CoListAgentFirstName': 0, 'CoListAgentLastName': 0, 'BuyerAgentMlsId': 0, 'BuyerAgentFirstName': 0, 'BuyerAgentLastName': 0, 'FireplacesTotal': 0, 'AssociationFeeFrequency': 0, 'AboveGradeFinishedArea': 0, 'ListingKeyNumeric': 0, 'MLSAreaMajor': 0, 'TaxAnnualAmount': 0, 'CountyOrParish': 0, 'MlsStatus': 0, 'ElementarySchool': 0, 'AttachedGarageYN': 0, 'ParkingTotal': 0, 'BuilderName': 0, 'PropertySubType': 0, 'LotSizeAcres': 0, 'SubdivisionName': 0, 'BuyerOfficeAOR': 0, 'YearBuilt': 0, 'StreetNumberNumeric': 0, 'ListingId': 0, 'Ba
# ...

# %%
df1 = pd.to_datetime(df['ListingContractDate'].copy(), errors = 'coerce')
df1.head()

df2 = pd.to_datetime(df['CloseDate'])
df2.dt.year.head()
# Out:
# 0    2026
# 1    2026
# 2    2026
# 3    2026
# 4    2026
# Name: CloseDate, dtype: int32

# %%
sold = pd.read_csv("sold_final.csv", low_memory=False)
listed = pd.read_csv("listed_final.csv", low_memory=False)

# converting to pandas datetimes
sold["CloseDate"] = pd.to_datetime(sold["CloseDate"], errors="coerce")
sold["ListingContractDate"] = pd.to_datetime(sold["ListingContractDate"], errors="coerce")
sold["PurchaseContractDate"] = pd.to_datetime(sold["PurchaseContractDate"], errors="coerce")
listed["ListingContractDate"] = pd.to_datetime(listed["ListingContractDate"], errors="coerce")

print(f"\nShape: {sold.shape}")
print(f"Rows: {sold.shape[0]}, Columns: {sold.shape[1]}")
print(f"\nColumn dtypes:\n{sold.dtypes.value_counts()}")
# Out:
# Shape: (397206, 89)
# Rows: 397206, Columns: 89
#
# Column dtypes:
# object            49
# float64           32
# int64              5
# datetime64[ns]     3
# Name: count, dtype: int64
# BuyerAgentAOR     12.35
# ListAgentAOR      11.62
# Flooring          35.84
# ViewYN             8.52
# WaterfrontYN      99.94
#                   ...
# price_per_sqft     0.06
# days_to_close      0.00
# year               0.00
# month              0.00
# property_age       0.09
# Length: 89, dtype: float64

# %%
# null analysis

missing = sold.isnull().sum()
missing_pct = round(missing / len(sold) * 100, 2)
missing_pct2 = (missing / len(sold) * 100).round(2)
print(missing_pct)
print(missing_pct2)
# Out:
# BuyerAgentAOR     12.35
# ListAgentAOR      11.62
# Flooring          35.84
# ViewYN             8.52
# WaterfrontYN      99.94
#                   ...
# price_per_sqft     0.06
# days_to_close      0.00
# year               0.00
# month              0.00
# property_age       0.09
# Length: 89, dtype: float64
# BuyerAgentAOR     12.35
# ListAgentAOR      11.62
# Flooring          35.84
# ViewYN             8.52
# WaterfrontYN      99.94
#                   ...
# price_per_sqft     0.06
# days_to_close      0.00
# year               0.00
# month              0.00
# property_age       0.09
# Length: 89, dtype: float64

# %%
df_listed_enriched = pd.read_csv('listed_enriched.csv')
df_sold_enriched = pd.read_csv('sold_enriched.csv')
# Out:
# /var/folders/zn/h8q2ztjx1dx0kx0hl7y57pdh0000gn/T/ipykernel_36567/3182049283.py:1: DtypeWarning: Columns (2,32,43,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listed_enriched = pd.read_csv('listed_enriched.csv')
# /var/folders/zn/h8q2ztjx1dx0kx0hl7y57pdh0000gn/T/ipykernel_36567/3182049283.py:2: DtypeWarning: Columns (0,1,4,9,64,78,79,80,82,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sold_enriched = pd.read_csv('sold_enriched.csv')

# %%
df_listed_enriched.head()
# Out:
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0          1340000.0  1074973329                    haleh360@Gmail.com
# 1          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 2          3150000.0  1074936537                      anader@dppre.com
# 3          3090000.0  1074917818                  QIANYU0607@GMAIL.COM
# 4         12725000.0  1074143166          jeff.williams@pacificsir.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN              Haleh       Dowlatshahi  34.052207
# 1       NaN         NaN              Renee              Chen  33.496363
# 2       NaN         NaN           Margaret             Nader  34.119345
# 3       NaN         NaN             QIANYU              GUAN  33.984057
# 4       NaN         NaN               Jeff          Williams  33.607583
#
#     Longitude                UnparsedAddress  ... AssociationFee  \
# ...

# %%
df_sold_enriched.head()
# Out:
#   BuyerAgentAOR ListAgentAOR          Flooring ViewYN WaterfrontYN BasementYN  \
# 0   Mlslistings  Mlslistings  Carpet,Tile,Wood   True          NaN        NaN
# 1      SanDiego     SanDiego               NaN  False          NaN        NaN
# 2      SanDiego     SanDiego               NaN  False          NaN        NaN
# 3   Mlslistings  Mlslistings               NaN  False          NaN        NaN
# 4     Southland    Southland               NaN  False          NaN        NaN
#
#   PoolPrivateYN  OriginalListPrice  ListingKey               ListAgentEmail  \
# 0         False           499000.0   551985747        jwachter@cbnorcal.com
# 1         False           759900.0   522107581         mdarwich12@gmail.com
# 2         False           739900.0   510919001         mdarwich12@gmail.com
# 3           NaN                NaN  1079166779       davidmartz@compass.com
# 4         False          1890500.0  1075037759  karen.klein@theagencyre.com
#
# ...

# %%
df_sold_cleaned = pd.read_csv('sold_cleaned.csv')
df_listed_cleaned = pd.read_csv('listed_cleaned.csv')
# Out:
# /var/folders/zn/h8q2ztjx1dx0kx0hl7y57pdh0000gn/T/ipykernel_36567/3340602915.py:1: DtypeWarning: Columns (0,1,7,51,63,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sold_cleaned = pd.read_csv('sold_cleaned.csv')
# /var/folders/zn/h8q2ztjx1dx0kx0hl7y57pdh0000gn/T/ipykernel_36567/3340602915.py:2: DtypeWarning: Columns (2,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listed_cleaned = pd.read_csv('listed_cleaned.csv')
